# %% [markdown]
# # Question 1

# %% [markdown]
# Our project aims to explore trends in data careers from 2017 to 2022 using six waves of cross-sectional survey data obtained from Kaggle. The datasets comprise survey responses that encompass demographics factors, salaries, job titles and the most used tech tools.
#
# Our project aims to tackle the need for insights into the evolution of data careers, which is crucial given the rapid growth and demand for data-related roles. By analyzing the data and applying data science techniques, we aim to gain insights into the demographics of professionals within the field, identify the essential skills and tools needed for a successful transition into data science and gain knowledge about the compensation for different roles in the industry.
#
# We aim to incorporate multiple topics covered throughout the CFG course. This includes using Python libraries, such as pandas, numpy, matplotlib, and scikit-learn, working with APIs, and  using machine learning. In particular, we aim to use an API in order to account for inflation in salaries over time and across regions, and we use machine learning via implementing an ordinal logistic regression model to help us predict which tools, demographic factors and data-science roles lead to the highest salaries in the data field.
#
# This question is particularly relevant for our team, as all are aiming to break into the data industry in the coming years. To come up with the question, we completed a Jamboard slide with our personal interests, as shown below.

# %% [markdown]
# ![personal_interests_homework.jpg](attachment:personal_interests_homework.jpg)

# %% [markdown]
# # Question 2

# %% [markdown]
# The target audience of our project is individuals interested in data careers. The findings of this project will provide insights into the demographics within the field, the required  skills/ tools for a successful transition, and the expected compensation for different roles in data science. These insights can help the target audience make informed decisions about their career choice.
#
# The expected level of expertise of the target audience will be minimal, given that an interest in pursuing a data career is not necessarily indicative of a prior skillset in the area. Therefore, while our analysis should be indicative of detailed trends, so as to be of use to the prospective data scientists/analysts/engineers seeking to choose a particular data career, the analysis will be explained/displayed in ways that a layperson can understand.

# %% [markdown]
# # Question 3

# %% [markdown]
# Our project aims to analyse trends in data careers from 2017 to 2022, primarily using six datasets obtained from Kaggle. These datasets comprise survey answers related to data careers, serving as our primary information source. However, we've identified potential issues with the datasets.
#
# First, different questions were asked across the years, resulting in variations in the column structures across the datasets.  To deal with this, we will clean the dataset of each year, dropping appropriate columns and re-structuring the datasets as needed prior to appending them.
#
# Second, some columns’ measures are captured differently across the years. For example, in earlier years, answers to how often certain tools, methods and platforms are used are captured on a 4 point likert scale -  “Rarely”, “Sometimes”, “Often” and “Most of the time”. In later years, the question is asking which tools, methods and platforms are regularly used, captured as binary measures - ‘Yes’ or ‘No’. To address this,  we have created a new variable for the answers in the earlier years, and re-coded the “Often” and “Most of the time” answers as ‘Yes’,  and the “Rarely”, “Sometimes” answers as ‘No’. This is because we can reasonably deduce the first two answers as equating to ‘regularly’.
#
# Third, the datasets’ multiple choice variables are not coded as 0 and 1, but rather with the name of a tool or with a null value, which will complicate our analyses when seeking to understand product popularity. To address this we will first check if any multiple choice question has gone completely unanswered, drop the rows of those that have been, and recode the answers as 0 or 1 accordingly.
#
# The fourth problem with our survey is the subjectivity involved in the survey answers, particularly in self-reported frequency of tools usage, categorised as "Rarely", "Sometimes", "Often", and "Most of the time". For instance, an individual who self-reports using TPUs "regularly" recorded usage between 15 to 25 times. Contrarily, another individual self-reporting as using TPUs "rarely" showed usage exceeding 25 times. These cases demonstrate the lack of quantitative standards for frequencies in our dataset. However, this doesn't significantly impact our core objective of providing valuable insights to prospective data professionals. Our focus is on capturing overarching trends, not the exact frequencies of tools usage. We believe that despite the subjectivity, the responses still offer a reliable gauge of tool usage trends in the data community.
#
# The fifth issue we need to consider is the bias in the dataset. Our dataset originates from surveys conducted on Kaggle, introducing a potential source of bias. As people who took this survey are all Kaggle users, our dataset cannot comprehensively represent the broader population of data scientists/analysts/engineers. Particularly, it might overlook data professionals who do not have access to Kaggle or choose not to use it. This aspect could limit the universality of our findings, making them more reflective of trends within the Kaggle community rather than the entire field of data science. While we acknowledge that our dataset may not capture the experiences of every data professional, especially those without access to Kaggle, the large and diverse user base of Kaggle still provides a rich, varied and representative subset of the data science community. The trends, tool usage patterns, and career paths observed within this subset can still offer meaningful and actionable insights for both aspiring and current data science professionals.
#
# Additionally, to enhance our insights, we'll use three APIs. The first, Google Trends will help gauge interest in data careers and tools over time and across countries. The second, Google Translate API will enable us to conduct Google Trend searches in different languages, ensuring data accuracy. Additionally, we'll use a third API to adjust for salary inflation over time and across various countries.

# %% [markdown]
# # Question 4

# %% [markdown]
# We plan to distribute the workload via a ticket system of task delegation and tracking. We have created a jamboard with five categories: to-dos, in progress, on-hold, completed, reviewed and submitted, and will keep track of the tasks, and who’s responsible for them via this method, much like in a traditional scrum team.
#
# We have also regularly scheduled group calls to ensure that every team member is on the same page while working on individual tasks. This allows us to discuss any challenges we may encounter, as well as sharing ideas on how to manipulate the data in the best possible way, across the multiple datasets.
#
# To best delegate tasks, we created a Jamboard slide for each team member to complete with their strengths and weaknesses. This has helped us delegate tasks to members whose strengths are aligned to the slide. Our team’s strengths and weaknesses are as follows:

# %%
![strengths_weaknesses_homework.jpg](attachment:strengths_weaknesses_homework.jpg)
# Out:
# '[strengths_weaknesses_homework.jpg]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# The team is managing the code via Google Collab. We have delegated a year of the cross-sectional survey data to each member of the team, and set up drop down tabs within Google Collab accordingly. With this, we are individually responsible for the coding of our dataset, but benefit from the joint knowledge/coding of the team, so that efforts are not duplicated. Once the cross-sectional datasets have been cleaned and appended, then we will continue to work in Google Collab individually, on particular sections of the project.
#
# Our expected timeline is as follows:
# Week 1: Finding appropriate data sets and devising an initial question set.
# Week 2: Data cleaning (via Google Colab), and appending cross sectional datasets.
# Week 3: Explorative analysis and refining question set.
# Week 4: Choosing final analysis, testing, and writing up the report.
